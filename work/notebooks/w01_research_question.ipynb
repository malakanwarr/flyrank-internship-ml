# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/malakanwarr/flyrank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# The label: a page is 'declining' when its recent trend is down. Simple, honest starter label.
df["is_declining_label"] = df["trend_direction"].str.lower().eq("down").astype(int)
print(df.shape[0], "pages |  declining rate:", round(df["is_declining_label"].mean(), 3))
# Out:
# 30000 pages |  declining rate: 0.542

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **My lane: Structured Content Archetype Clustering.
# I chose this lane because I'm intersted to find what kind of different types of pages exist in our data and I'm excited to put them in groups, discover the differences due to the metrices and giving them different names.**

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **The Decision: This work improves how the business prioritizes content updates. Instead of guessing which pages to fix, clustering allows us to automatically group underperforming pages by their shared symptoms so we know exactly what strategy to apply to each group.
# The Action (Who acts on it): The Content and SEO teams will act on this by taking specific actions (like rewriting, combining, or deleting) tailored to each specific cluster.
# The Cost of a Wrong Call: A wrong recommendation causes a massive waste of human effort. If the model groups pages incorrectly, the writing team will waste hours trying to fix pages that are unfixable, while ignoring the hidden gems that actually needed attention.**

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# **I am choosing this lane because the data is highly diverse. For example, search_volume range from 0 to 74000, and 90-day impressions range from 1 to 517715, proving that a 'one-size-fits-all' strategy won't work and we need to group these into distinct archetypes.**

# %%
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# This code prints the exact min and max word counts to back your text!
print("Min search volume: ", df["search_volume"].min())
print("Max search volume: ", df["search_volume"].max())

print("Min 90-day impressions: ", df["impressions_90d"].min())
print("Max 90-day impressions: ", df["impressions_90d"].max())
# Out:
# Min search volume:  0.0
# Max search volume:  74000.0
# Min 90-day impressions:  1
# Max 90-day impressions:  517715

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **What I can claim: My work will provide observed, directional insights and decision-support archetypes. It can show that certain groups of pages share similar traffic and structural traits, helping the content team prioritize which categories to review first.
# What I cannot claim: My work will not prove causal relationships (example I cannot claim that clustering or rewriting a page causes a traffic recovery). It also does not predict Google's algorithm or reverse-engineer search engine ranking factors; it is strictly an observational grouping tool.**

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
